# %% [markdown]
# <a href="https://colab.research.google.com/github/rk928/Ranjit-Kumar/blob/main/ENVS_617_Assignment_2_Pandas_Tidying.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignment 2: Pandas & Data Tidying
#
# In this assignment we will load a dataset and tidy it a bit so it can spark joy!
#
#
# The dataset we are using describes 2013 greenhouse gas emissions from food products. This data can be viewed in a nicely visualized form at Our World in Data [here](https://ourworldindata.org/environmental-impacts-of-food), but the original data comes from [this paper](https://ourworldindata.org/environmental-impacts-of-food#explore-data-on-the-environmental-impacts-of-food) published in *Science* in 2018. (The data we're using is "File (aaq0216_datas2.xls)", linked at the bottom of the webpage.)
#
# We downloaded the data *exactly* as it was linked in the *Science* paper, and uploaded the raw Excel to out GitHub repository.
#
# We will be working with the raw data like the data scientists we are!
#
# NOTE: For this assignment, when we ask a question, please add a text field with your answer. (No need to write more than a few sentences, maximum.) If the question requires code, use the code field there or add one.

# %% [markdown]
# # Part 1: Load the data
#
# First, load the data and create a pandas dataframe called `df_ghg`. The steps below breakdown the process:

# %% [markdown]
# 1. Import the pandas package

# %%
import pandas as pd

# %% [markdown]
# 2. Load the Excel data into `df_ghg` from the GitHub link here:
#
#   `https://github.com/envirodatascience/ENVS-617-Class-Data/blob/main/aaq0216_datas2.xls?raw=true`
#
#   Reading in this data will be an iterative process. For now, just take a first stab at reading in the data in *some* format.
#
#   Display a preview of your initial results.

# %%
df_ghg = pd.read_excel("https://github.com/envirodatascience/ENVS-617-Class-Data/blob/main/aaq0216_datas2.xls?raw=true")
df_ghg
# Out:
#                                            Unnamed: 0  \
# 0                                                 NaN
# 1                                             Product
# 2                                 Wheat & Rye (Bread)
# 3                                        Maize (Meal)
# 4                                       Barley (Beer)
# 5                                             Oatmeal
# 6                                                Rice
# 7                                            Potatoes
# 8                                             Cassava
# 9                                          Cane Sugar
# 10                                         Beet Sugar
# 11                                       Other Pulses
# 12                                               Peas
# 13                                               Nuts
# 14                                         Groundnuts
# 15                                            Soymilk
# 16                                               Tofu
# 17                                        Soybean Oil
# 18                                           Palm Oil
# 19                                      Sunflower Oil
# 20                                       Rapeseed Oil
# 21                                          Olive Oil
# 22                                           Tomatoes
# 23                                     Onions & Leeks
# 24                                    Root Vegetables
# 25                                          Brassicas
# 26                                   Other Vegetables
# 27                                       Citrus Fruit
# 28                                            Bananas
# 29                                             Apples
# 30                                   Berries & Grapes
# 31                                               Wine
# 32                                        Other Fruit
# 33                                             Coffee
# 34                                     Dark Chocolate
# 35                            Bovine Meat (beef herd)
# 36                           Bovine Meat (dairy herd)
# 37                                      Lamb & Mutton
# 38                                           Pig Meat
# 39                                       Poultry Meat
# 40                                               Milk
# 41                                             Cheese
# 42                                               Eggs
# 43                                      Fish (farmed)
# 44                               Crustaceans (farmed)
# 45                                                NaN
# 46  Note: See table S1 for definitions of retail w...
#
#    Resampled, Randomized Data Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0            Land Use (m2/FU)        NaN        NaN        NaN        NaN
# 1                    5th pctl  10th pctl       Mean     Median  90th pctl
# 2                        0.98       1.11       3.85        2.7       7.87
# 3                        0.99       1.14       2.94       1.84        5.7
# 4                        0.21       0.26       1.11       0.88       2.37
# 5                        2.64       2.85        7.6       7.72      12.88
# 6                        0.99        1.1        2.8       2.15       6.21
# 7                        0.37       0.44       0.88       0.82        1.4
# 8                        0.73       0.76       1.81       1.32       3.19
# 9                        1.14       1.17       2.04       1.78       3.11
# 10                       1.11       1.19       1.83       1.52       3.09
# 11                       4.08       9.93      15.57      12.24      41.25
# 12                       2.28       2.77       7.46       6.73      14.19
# 13                       4.15       4.49      12.96       8.73      26.59
# 14                       4.22       4.67       9.11       7.87      15.38
# 15                        0.3       0.34       0.66       0.64       0.92
# 16                       1.57       1.77       3.52       3.41       4.94
# 17                       4.77       5.25      10.52       9.61      14.64
# 18                       1.37       1.67       2.42       2.39       2.99
# 19                        7.5       8.37      17.66       16.3      27.04
# 20                       5.01       5.22      10.63       9.42      19.04
# 21                       7.85       7.85      26.31      17.29      36.32
# 22                       0.07       0.09        0.8       0.17       0.93
# 23                        0.1        0.1       0.39        0.3       0.62
# 24                       0.16       0.17       0.33       0.27       0.32
# 25                       0.19       0.19       0.55       0.34        0.8
# 26                       0.17       0.17       0.38       0.19       0.77
# 27                       0.29       0.35       0.86       0.68       1.75
# 28                       0.22       0.28       1.93       1.39       2.99
# 29                        0.3       0.31       0.63       0.51       0.99
# 30                       0.23       0.25       2.41       2.58       6.85
# 31                       0.86       0.86       1.78       1.64       2.76
# 32                       0.21       0.21       0.89       0.92       1.42
# 33                        8.3       8.44      21.62       11.9      40.28
# 34                      21.57       34.7      68.96      53.83     123.26
# 35                      70.41      82.84     326.21     170.37     735.09
# 36                      12.27      14.39      43.24      25.94      64.12
# 37                      47.85      60.06     369.81     127.41     442.34
# 38                       7.39       7.76      17.36      13.44      31.11
# 39                       6.46       6.65      12.22      11.01      16.02
# 40                        0.8       1.11       8.95        2.1        9.3
# 41                       7.86       9.55      87.79      20.18     239.21
# 42                       4.25       4.38       6.27       5.71       8.79
# 43                        0.3       0.82       8.41        5.6       10.5
# 44                        0.6       0.61       2.97       0.82       5.19
# 45                        NaN        NaN        NaN        NaN        NaN
# 46                        NaN        NaN        NaN        NaN        NaN
#
#    Unnamed: 6                                         Unnamed: 7 Unnamed: 8  \
# 0         NaN  GHG Emissions (kg CO2eq/FU, IPCC 2013 incl. CC...        NaN
# 1   95th pctl                                           5th pctl  10th pctl
# 2        9.96                                               0.71       0.79
# 3        9.01                                               0.66       0.73
# 4        2.87                                               0.59        0.7
# 5       13.98                                                0.8       0.85
# 6        7.21                                               1.15       1.46
# 7        1.66                                               0.09       0.16
# 8        3.28                                               0.26       0.35
# 9        3.53                                               0.62       0.92
# 10       3.29                                               1.01       1.21
# 11      41.87                                               0.89       0.98
# 12      20.47                                               0.51       0.56
# 13      26.59                                              -4.02      -3.65
# 14      15.38                                               1.42       1.63
# 15       1.07                                               0.51       0.58
# 16       5.87                                               1.41        1.6
# 17      17.47                                               2.16       2.43
# 18       3.29                                               2.78       3.61
# 19      29.69                                               2.17       2.46
# 20      20.97                                               2.23        2.5
# 21      36.32                                               2.13       2.86
# 22       5.62                                               0.37       0.39
# 23       0.62                                               0.28        0.3
# 24       0.45                                               0.21       0.24
# 25        2.3                                               0.21       0.23
# 26       1.07                                               0.21       0.23
# 27       1.75                                               0.01       0.08
# 28       9.44                                               0.56       0.61
# 29       1.02                                               0.26       0.29
# 30       6.86                                               0.64       0.77
# 31       3.48                                               0.74       0.91
# 32       1.85                                               0.27       0.35
# 33      40.66                                               4.35        5.2
# 34     144.66                                              -3.95       -0.1
# 35      910.1                                              37.57      40.37
# 36     106.37                                              14.93      17.94
# 37     724.65                                               23.7      24.52
# 38      34.09                                               6.91       7.41
# 39       20.4                                               3.95       4.18
# 40      32.19                                               1.51        1.7
# 41     323.45                                              10.21      10.92
# 42       8.81                                               2.85       2.93
# 43      26.26                                               5.41       5.65
# 44        5.2                                               7.41       8.04
# 45        NaN                                                NaN        NaN
# 46        NaN                                                NaN        NaN
#
#    Unnamed: 9  ...                                      Unnamed: 45  \
# 0         NaN  ...  GHG (kg CO2eq/FU, IPCC 2013 incl. CC feedbacks)
# 1        Mean  ...                                              Min
# 2        1.57  ...                                         0.417098
# 3         1.7  ...                                         0.453814
# 4        1.18  ...                                         0.439197
# 5        2.48  ...                                         0.768921
# 6        4.45  ...                                         1.127204
# 7        0.46  ...                                         0.099775
# 8        1.32  ...                                         0.214239
# 9         3.2  ...                                         0.551047
# 10       1.81  ...                                         0.934153
# 11       1.79  ...                                         0.665679
# 12       0.98  ...                                         0.448359
# 13       0.43  ...                                        -8.088359
# 14       3.23  ...                                         1.280465
# 15       0.98  ...                                         0.700825
# 16       3.16  ...                                          1.70523
# 17       6.32  ...                                         2.162778
# 18       7.32  ...                                        -0.266883
# 19        3.6  ...                                         2.138707
# 20       3.77  ...                                         1.952156
# 21       5.42  ...                                         1.885738
# 22       2.09  ...                                         0.222899
# 23        0.5  ...                                         0.175612
# 24       0.43  ...                                         0.169445
# 25       0.51  ...                                         0.217305
# 26       0.53  ...                                          0.09181
# 27       0.39  ...                                         0.019096
# 28       0.86  ...                                         0.488926
# 29       0.43  ...                                         0.166292
# 30       1.53  ...                                         0.431204
# 31       1.79  ...                                          0.96862
# 32       1.05  ...                                         0.032885
# 33      28.53  ...                                         4.727222
# 34      46.65  ...                                        -3.909216
# 35      99.48  ...                                        35.062785
# 36       33.3  ...                                         9.567208
# 37      39.72  ...                                        21.781948
# 38      12.31  ...                                         6.635532
# 39       9.87  ...                                         4.033998
# 40       3.15  ...                                         1.345405
# 41      23.88  ...                                         9.026556
# 42       4.67  ...                                           2.5621
# 43      13.63  ...                                         5.205339
# 44      26.87  ...                                         8.325215
# 45        NaN  ...                                              NaN
# 46        NaN  ...                                              NaN
#
#    Unnamed: 46                         Unnamed: 47  Unnamed: 48  \
# 0          NaN  Acid. (kg SO2eq/FU, CML2 Baseline)          NaN
# 1          Max                                 Min          Max
# 2    56.043627                            3.407876    33.477292
# 3    72.276385                            2.923807    25.476467
# 4     2.639285                            4.822939    38.361277
# 5     4.263916                            4.773492    28.592331
# 6    14.394758                            5.864225    88.874015
# 7     1.627327                               2.058    10.932167
# 8    36.181402                            2.641721     5.818416
# 9    47.581663                            4.983017    38.031184
# 10    3.464563                            4.409712     68.59162
# 11    5.265505                            3.933794    36.788666
# 12    2.294712                            3.110063    20.622533
# 13   23.677203                            10.92617   119.175042
# 14    6.180464                            9.233708    57.026162
# 15    1.889881                            3.182235     4.782195
# 16     8.07427                            8.832082    17.431621
# 17   21.308473                           11.418939    36.181485
# 18   14.173021                             6.81138    22.546243
# 19    7.734857                            8.710571    66.320864
# 20   13.638055                           11.979827   190.760546
# 21   20.273985                            9.829239   111.775327
# 22    28.96176                            2.937925   240.623773
# 23    0.857266                            2.454607     4.784732
# 24     1.47389                            2.345777     4.261906
# 25    2.362437                            1.930353    10.612753
# 26   12.348197                            1.457194    62.911647
# 27    2.655811                            1.727813     6.427327
# 28    1.618831                            3.360185    13.771747
# 29    1.202193                            1.465131     5.530368
# 30    8.408536                            2.838724    87.722396
# 31    4.701181                            5.612987    35.684354
# 32    4.898787                            3.118368    22.114821
# 33   84.586192                           33.351264   181.564745
# 34  257.945181                            6.002274   167.499601
# 35  432.047259                           59.778823   807.636218
# 36   73.921818                          136.277545  1155.193201
# 37   72.142416                            81.43016   478.464223
# 38   27.645756                           57.888883   467.297798
# 39   47.701887                           29.987429   591.814061
# 40   14.577053                            5.646225    33.477937
# 41  150.519031                             37.4553   290.405757
# 42    8.440272                           20.261383    88.748068
# 43   87.778273                           27.847193     239.0826
# 44   99.042589                           63.823094   487.796759
# 45         NaN                                 NaN          NaN
# 46         NaN                                 NaN          NaN
#
#                              Unnamed: 49  Unnamed: 50      Unnamed: 51  \
# 0   Eutr. (kg PO43-eq/FU, CML2 Baseline)          NaN  Fresh W. (L/FU)
# 1                                    Min          Max              Min
# 2                                0.16895    77.377291         1.140702
# 3                               0.780147    20.807681                0
# 4                               1.044854    12.371997         6.230092
# 5                               3.402989    25.382344                0
# 6                               2.089442   172.102962                0
# 7                               0.633825    12.056213                0
# 8                               0.494759     0.834219                0
# 9                               2.475257   133.728915         7.164531
# 10                              2.105777    16.578184        10.281537
# 11                               0.77661    48.944426                0
# 12                              0.787241    33.643861                0
# 13                              5.344289    90.741576                0
# 14                              5.086438    19.669687                0
# 15                              0.516282     4.280018         1.159283
# 16                              2.934621    23.118954          6.01997
# 17                              2.612739    61.125944         1.442194
# 18                              1.898456    17.100055         5.876381
# 19                              7.546945   175.685435         2.727067
# 20                               3.33076    66.646627         1.361106
# 21                              3.206823    63.740774         3.213778
# 22                              0.250973   116.250136         3.909905
# 23                              0.657271     7.440024                0
# 24                              0.494682     9.892292                0
# 25                              0.935222     6.644021                0
# 26                              0.282795    15.513052         0.408163
# 27                              0.250664     6.478692                0
# 28                               1.53739    37.368541                0
# 29                              0.204962     4.238972                0
# 30                              0.556421    17.421519        10.949294
# 31                              0.446179     12.43086         1.633157
# 32                              0.665186    20.085365                0
# 33                             15.575616    268.79595        10.405013
# 34                              3.384082   237.740632         6.681145
# 35                             80.825249   669.543547       101.045738
# 36                              83.19075  2637.267651       187.416068
# 37                             23.484294    205.46031        86.273866
# 38                             29.427885   236.701373        67.364324
# 39                             22.912939   305.697007        19.121726
# 40                              2.155756     27.90626         7.677393
# 41                             20.363466   248.506898        60.252908
# 42                             11.969206    40.579729       139.672388
# 43                             18.391414  3505.641364       135.949194
# 44                             68.557067  1147.461202                0
# 45                                   NaN          NaN              NaN
# 46                                   NaN          NaN              NaN
#
#       Unnamed: 52         Unnamed: 53     Unnamed: 54
# 0             NaN  Strs. W. WU (L/FU)             NaN
# 1             Max                 Min             Max
# 2     8675.359047            1.395022   333260.436228
# 3     7190.948767                   0   461216.164137
# 4      568.804918            4.422704    41483.803982
# 5     1791.100466                   0   105303.865196
# 6    12406.611092                   0   832397.387121
# 7      834.365165                   0     40553.99636
# 8               0                   0               0
# 9     7770.099414            8.516151   359239.122185
# 10     1900.06263            9.934868    87128.546102
# 11    7538.272103                   0   432637.417155
# 12    4050.646778                   0    302949.73582
# 13   11383.532966                   0   807659.273424
# 14    6524.680483                   0   195134.858891
# 15     209.079386            1.002279    19424.656133
# 16    1123.970966            5.204676   104435.414067
# 17    3294.384177            1.246876    307031.50113
# 18       7.413145            3.682467       67.222093
# 19    5977.160044            2.357736   519840.661037
# 20    12110.24951            0.910809  1044364.866454
# 21     6907.50549           130.31638   621151.527083
# 22    4542.277037            12.81487    24103.463802
# 23      75.468855                   0     5222.183617
# 24       92.53612                   0     6816.234648
# 25     656.458886                   0    62328.696849
# 26    1435.818583            0.379416    78311.648189
# 27     517.825561                   0    46578.869715
# 28     854.676194                   0     6147.138872
# 29    1775.631432                   0    52971.736354
# 30    1026.687996           20.232867    43007.422552
# 31     593.869344            1.341377    36973.401555
# 32    2506.628291                   0    142268.55245
# 33      38.279714             5.08441      811.174928
# 34   35511.362436            5.146018   164085.681524
# 35   26951.042253          170.361312  1569705.822849
# 36    9328.980045          267.387517   233168.426406
# 37    9338.017854          995.283212   689108.346254
# 38    6318.158326           51.630386   236070.732342
# 39    4710.253379           21.131728   214879.147983
# 40    4233.621594           15.969382    90838.072539
# 41    45167.22543          136.836841   969209.819233
# 42     2145.41223          411.698979    97886.672208
# 43  110939.557394          786.974746   182625.096274
# 44   34806.784616                   0  1308548.040675
# 45            NaN                 NaN             NaN
# 46            NaN                 NaN             NaN
#
# [47 rows x 55 columns]

# %%
df_ghg.head()
# Out:
#             Unnamed: 0 Resampled, Randomized Data Unnamed: 2 Unnamed: 3  \
# 0                  NaN           Land Use (m2/FU)        NaN        NaN
# 1              Product                   5th pctl  10th pctl       Mean
# 2  Wheat & Rye (Bread)                       0.98       1.11       3.85
# 3         Maize (Meal)                       0.99       1.14       2.94
# 4        Barley (Beer)                       0.21       0.26       1.11
#
#   Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0        NaN        NaN        NaN
# 1     Median  90th pctl  95th pctl
# 2        2.7       7.87       9.96
# 3       1.84        5.7       9.01
# 4       0.88       2.37       2.87
#
#                                           Unnamed: 7 Unnamed: 8 Unnamed: 9  \
# 0  GHG Emissions (kg CO2eq/FU, IPCC 2013 incl. CC...        NaN        NaN
# 1                                           5th pctl  10th pctl       Mean
# 2                                               0.71       0.79       1.57
# 3                                               0.66       0.73        1.7
# 4                                               0.59        0.7       1.18
#
#    ...                                      Unnamed: 45 Unnamed: 46  \
# 0  ...  GHG (kg CO2eq/FU, IPCC 2013 incl. CC feedbacks)         NaN
# 1  ...                                              Min         Max
# 2  ...                                         0.417098   56.043627
# 3  ...                                         0.453814   72.276385
# 4  ...                                         0.439197    2.639285
#
#                           Unnamed: 47 Unnamed: 48  \
# 0  Acid. (kg SO2eq/FU, CML2 Baseline)         NaN
# 1                                 Min         Max
# 2                            3.407876   33.477292
# 3                            2.923807   25.476467
# 4                            4.822939   38.361277
#
#                             Unnamed: 49 Unnamed: 50      Unnamed: 51  \
# 0  Eutr. (kg PO43-eq/FU, CML2 Baseline)         NaN  Fresh W. (L/FU)
# 1                                   Min         Max              Min
# 2                               0.16895   77.377291         1.140702
# 3                              0.780147   20.807681                0
# 4                              1.044854   12.371997         6.230092
#
#    Unnamed: 52         Unnamed: 53    Unnamed: 54
# 0          NaN  Strs. W. WU (L/FU)            NaN
# 1          Max                 Min            Max
# 2  8675.359047            1.395022  333260.436228
# 3  7190.948767                   0  461216.164137
# 4   568.804918            4.422704   41483.803982
#
# [5 rows x 55 columns]

# %%
df_ghg.tail()
# Out:
#                                            Unnamed: 0  \
# 42                                               Eggs
# 43                                      Fish (farmed)
# 44                               Crustaceans (farmed)
# 45                                                NaN
# 46  Note: See table S1 for definitions of retail w...
#
#    Resampled, Randomized Data Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 42                       4.25       4.38       6.27       5.71       8.79
# 43                        0.3       0.82       8.41        5.6       10.5
# 44                        0.6       0.61       2.97       0.82       5.19
# 45                        NaN        NaN        NaN        NaN        NaN
# 46                        NaN        NaN        NaN        NaN        NaN
#
#    Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 45 Unnamed: 46  \
# 42       8.81       2.85       2.93       4.67  ...      2.5621    8.440272
# 43      26.26       5.41       5.65      13.63  ...    5.205339   87.778273
# 44        5.2       7.41       8.04      26.87  ...    8.325215   99.042589
# 45        NaN        NaN        NaN        NaN  ...         NaN         NaN
# 46        NaN        NaN        NaN        NaN  ...         NaN         NaN
#
#    Unnamed: 47 Unnamed: 48 Unnamed: 49  Unnamed: 50 Unnamed: 51  \
# 42   20.261383   88.748068   11.969206    40.579729  139.672388
# 43   27.847193    239.0826   18.391414  3505.641364  135.949194
# 44   63.823094  487.796759   68.557067  1147.461202           0
# 45         NaN         NaN         NaN          NaN         NaN
# 46         NaN         NaN         NaN          NaN         NaN
#
#       Unnamed: 52 Unnamed: 53     Unnamed: 54
# 42     2145.41223  411.698979    97886.672208
# 43  110939.557394  786.974746   182625.096274
# 44   34806.784616           0  1308548.040675
# 45            NaN         NaN             NaN
# 46            NaN         NaN             NaN
#
# [5 rows x 55 columns]

# %%
df_ghg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47 entries, 0 to 46
# Data columns (total 55 columns):
#  #   Column                                                                                         Non-Null Count  Dtype
# ---  ------                                                                                         --------------  -----
#  0   Unnamed: 0                                                                                     45 non-null     object
#  1   Resampled, Randomized Data                                                                     45 non-null     object
#  2   Unnamed: 2                                                                                     44 non-null     object
#  3   Unnamed: 3                                                                                     44 non-null     object
#  4   Unnamed: 4                                                                                     44 non-null     object
#  5   Unnamed: 5                                                                                     44 non-null     object
#  6   Unnamed: 6                                                                                     44 non-null     object
#  7   Unnamed: 7                                                                                     45 non-null     object
#  8   Unnamed: 8                                                                                     44 non-null     object
#  9   Unnamed: 9                                                                                     44 non-null     object
#  10  Unnamed: 10                                                                                    44 non-null     object
#  11  Unnamed: 11                                                                                    44 non-null     object
#  12  Unnamed: 12                                                                                    44 non-null     object
#  13  Unnamed: 13                                                                                    45 non-null     object
#  14  Unnamed: 14                                                                                    44 non-null     object
#  15  Unnamed: 15                                                                                    44 non-null     object
#  16  Unnamed: 16                                                                                    44 non-null     object
#  17  Unnamed: 17                                                                                    44 non-null     object
#  18  Unnamed: 18                                                                                    44 non-null     object
#  19  Unnamed: 19                                                                                    45 non-null     object
#  20  Unnamed: 20                                                                                    44 non-null     object
#  21  Unnamed: 21                                                                                    44 non-null     object
#  22  Unnamed: 22                                                                                    44 non-null     object
#  23  Unnamed: 23                                                                                    44 non-null     object
#  24  Unnamed: 24                                                                                    44 non-null     object
#  25  Unnamed: 25                                                                                    45 non-null     object
#  26  Unnamed: 26                                                                                    44 non-null     object
#  27  Unnamed: 27                                                                                    44 non-null     object
#  28  Unnamed: 28                                                                                    44 non-null     object
#  29  Unnamed: 29                                                                                    44 non-null     object
#  30  Unnamed: 30                                                                                    44 non-null     object
#  31  Unnamed: 31                                                                                    45 non-null     object
#  32  Unnamed: 32                                                                                    44 non-null     object
#  33  Unnamed: 33                                                                                    44 non-null     object
#  34  Unnamed: 34                                                                                    44 non-null     object
#  35  Unnamed: 35                                                                                    44 non-null     object
#  36  Unnamed: 36                                                                                    44 non-null     object
#  37  Unnamed: 37                                                                                    45 non-null     object
#  38  Unnamed: 38                                                                                    44 non-null     object
#  39  Unnamed: 39                                                                                    44 non-null     object
#  40  Unnamed: 40                                                                                    44 non-null     object
#  41  Unnamed: 41                                                                                    44 non-null     object
#  42  Unnamed: 42                                                                                    44 non-null     object
#  43  Data Without Resampling or Randomization (original study data, after harmonizing methodology)  45 non-null     object
#  44  Unnamed: 44                                                                                    44 non-null     object
#  45  Unnamed: 45                                                                                    45 non-null     object
#  46  Unnamed: 46                                                                                    44 non-null     object
#  47  Unnamed: 47                                                                                    45 non-null     object
#  48  Unnamed: 48                                                                                    44 non-null     object
#  49  Unnamed: 49                                                                                    45 non-null     object
#  50  Unnamed: 50                                                                                    44 non-null     object
#  51  Unnamed: 51                                                                                    45 non-null     object
#  52  Unnamed: 52                                                                                    44 non-null     object
#  53  Unnamed: 53                                                                                    45 non-null     object
#  54  Unnamed: 54                                                                                    44 non-null     object
# dtypes: object(55)
# memory usage: 20.3+ KB

# %% [markdown]
# 3. Raw data does not always come in a tidy format! Take a moment to orient yourself to what is going on in this Excel data. Feel free to open the Excel file directly to have a look (paste the GitHub link into a browser or download from the *Science* link above).
#
#   How is this Excel organized?

# %% [markdown]
# 4. For this assignment, we only care about the data on 2013 greenhouse gas emissions for each food item. Specifically, we only care about the food product field, and the data fields within `GHG Emissions (kg CO2eq/FU, IPCC 2013 incl. CC feedbacks)`
#
#   Read in this subsest of the data and display the entire dataframe. Make sure you have a single header row, and no extra "notes" rows at the bottom.
#
#   HINT: you will likely want to use the following arguments to specify what data should be read in:
#     * `usecols=`: A list of integers representing the column numbers (0-indexed) to be read in
#     * `skiprows=`: The number (integer) of lines to skip at the start of the file
#     * `skipfooter=`: The number (integer) of lines to drop at the bottom of the file
#
#   This is tricky! Don't be afraid to experiment.

# %%
df_ghg_emissions = df_ghg.iloc[2:,[0,7]]
df_ghg_emissions.head()
df_ghg_emissions.tail()
# Out:
#                                            Unnamed: 0 Unnamed: 7
# 42                                               Eggs       2.85
# 43                                      Fish (farmed)       5.41
# 44                               Crustaceans (farmed)       7.41
# 45                                                NaN        NaN
# 46  Note: See table S1 for definitions of retail w...        NaN

# %%
df_ghg_emissions = df_ghg_emissions.rename(columns={"Unnamed: 0":"Food Product", "Unnamed: 7":"GHG Emissions (kg CO2eq/FU, IPCC 2013 incl. CC..."} )
df_ghg_emissions.head()
# Out:
#           Food Product GHG Emissions (kg CO2eq/FU, IPCC 2013 incl. CC...
# 2  Wheat & Rye (Bread)                                              0.71
# 3         Maize (Meal)                                              0.66
# 4        Barley (Beer)                                              0.59
# 5              Oatmeal                                               0.8
# 6                 Rice                                              1.15

# %%
df_ghg_emissions.tail()
# Out:
#                                          Food Product  \
# 42                                               Eggs
# 43                                      Fish (farmed)
# 44                               Crustaceans (farmed)
# 45                                                NaN
# 46  Note: See table S1 for definitions of retail w...
#
#    GHG Emissions (kg CO2eq/FU, IPCC 2013 incl. CC...
# 42                                              2.85
# 43                                              5.41
# 44                                              7.41
# 45                                               NaN
# 46                                               NaN

# %%
df_ghg_emissions = df_ghg_emissions.drop(df_ghg_emissions.tail(1).index)
df_ghg_emissions.tail()
# Out:
#             Food Product GHG Emissions (kg CO2eq/FU, IPCC 2013 incl. CC...
# 41                Cheese                                             10.21
# 42                  Eggs                                              2.85
# 43         Fish (farmed)                                              5.41
# 44  Crustaceans (farmed)                                              7.41
# 45                   NaN                                               NaN

# %%
df_ghg_emissions.head()
# Out:
#           Food Product GHG Emissions (kg CO2eq/FU, IPCC 2013 incl. CC...
# 2  Wheat & Rye (Bread)                                              0.71
# 3         Maize (Meal)                                              0.66
# 4        Barley (Beer)                                              0.59
# 5              Oatmeal                                               0.8
# 6                 Rice                                              1.15

# %% [markdown]
# 5. Our data is now tidy! But we did drop some information when we dropped some of the headers. Let's add that information into new columns in our tidy dataframe. We'll "hardcode" these new columns, meaning we'll explicitly and statically define them from scratch.
#
#   Create a column `Year` with the year covered by this data

# %%
df_ghg_emissions["Year"] = 2013
df_ghg_emissions.head()
# Out:
#           Food Product GHG Emissions (kg CO2eq/FU, IPCC 2013 incl. CC...  Year
# 2  Wheat & Rye (Bread)                                              0.71  2013
# 3         Maize (Meal)                                              0.66  2013
# 4        Barley (Beer)                                              0.59  2013
# 5              Oatmeal                                               0.8  2013
# 6                 Rice                                              1.15  2013

# %% [markdown]
# 6. Create a column `Units` that includes the scientific units for this data

# %%
df_ghg_emissions["Units"] = "kg CO2eq/FU, IPCC 2013 incl. CC feedbacks"
df_ghg_emissions.head()
# Out:
#           Food Product GHG Emissions (kg CO2eq/FU, IPCC 2013 incl. CC...  \
# 2  Wheat & Rye (Bread)                                              0.71
# 3         Maize (Meal)                                              0.66
# 4        Barley (Beer)                                              0.59
# 5              Oatmeal                                               0.8
# 6                 Rice                                              1.15
#
#    Year                                      Units
# 2  2013  kg CO2eq/FU, IPCC 2013 incl. CC feedbacks
# 3  2013  kg CO2eq/FU, IPCC 2013 incl. CC feedbacks
# 4  2013  kg CO2eq/FU, IPCC 2013 incl. CC feedbacks
# 5  2013  kg CO2eq/FU, IPCC 2013 incl. CC feedbacks
# 6  2013  kg CO2eq/FU, IPCC 2013 incl. CC feedbacks

# %% [markdown]
# 7. We've added information on the dates and units for this data, but it is still not very clear (from a quick glance) what this data is representing. Let's add one more column `Measure` with a short, readable description of the numerical data: "2013 GHG Emiss."
#
#   Create `Measure` by referencing the `Year` column you already created. You will need to cast that column. (Note: it's generally a good idea to define new things by referencing old things - that way, if you ever need to make a change, you only need to make a chance in one place. All other changes will flow through.)
#
#   Check that `Measure` is correctly defined by displaying your results.

# %%
df_ghg_emissions["Measure"] = "2013 GHG Emiss."
df_ghg_emissions.head()
# Out:
#           Food Product GHG Emissions (kg CO2eq/FU, IPCC 2013 incl. CC...  \
# 2  Wheat & Rye (Bread)                                              0.71
# 3         Maize (Meal)                                              0.66
# 4        Barley (Beer)                                              0.59
# 5              Oatmeal                                               0.8
# 6                 Rice                                              1.15
#
#    Year                                      Units          Measure
# 2  2013  kg CO2eq/FU, IPCC 2013 incl. CC feedbacks  2013 GHG Emiss.
# 3  2013  kg CO2eq/FU, IPCC 2013 incl. CC feedbacks  2013 GHG Emiss.
# 4  2013  kg CO2eq/FU, IPCC 2013 incl. CC feedbacks  2013 GHG Emiss.
# 5  2013  kg CO2eq/FU, IPCC 2013 incl. CC feedbacks  2013 GHG Emiss.
# 6  2013  kg CO2eq/FU, IPCC 2013 incl. CC feedbacks  2013 GHG Emiss.

# %% [markdown]
# # Part 2: Orienting
# Our data is loaded cleanly! Now it's time to understand what it is representing. Answer the prompts below with code and/or text.

# %% [markdown]
# 1. What do the columns represent? Feel free to check the original links for info.

# %%
df_ghg_emissions.columns
# Out:
# Index(['Food Product', 'GHG Emissions (kg CO2eq/FU, IPCC 2013 incl. CC...',
#        'Year', 'Units', 'Measure'],
#       dtype='object')

# %% [markdown]
# 2. What are the dimensions of the data?

# %%
df_ghg_emissions.shape
# Out:
# (44, 5)

# %% [markdown]
# It has 44 rows and 5 columns

# %% [markdown]
# 3. What is the type of each column. Do any columns have null values?

# %%
df_ghg_emissions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44 entries, 2 to 45
# Data columns (total 5 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   Food Product                                       43 non-null     object
#  1   GHG Emissions (kg CO2eq/FU, IPCC 2013 incl. CC...  43 non-null     object
#  2   Year                                               44 non-null     int64
#  3   Units                                              44 non-null     object
#  4   Measure                                            44 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 1.8+ KB

# %% [markdown]
# 4. How many unique food items are measured?

# %%
df_ghg_emissions["Food Product"].nunique()
# Out:
# 43

# %% [markdown]
# 5. What are the unique food items that are measured?

# %%
df_ghg_emissions["Food Product"].unique()
# Out:
# array(['Wheat & Rye (Bread)', 'Maize (Meal)', 'Barley (Beer)', 'Oatmeal',
#        'Rice', 'Potatoes', 'Cassava', 'Cane Sugar', 'Beet Sugar',
#        'Other Pulses', 'Peas', 'Nuts', 'Groundnuts', 'Soymilk', 'Tofu',
#        'Soybean Oil', 'Palm Oil', 'Sunflower Oil', 'Rapeseed Oil',
#        'Olive Oil', 'Tomatoes', 'Onions & Leeks', 'Root Vegetables',
#        'Brassicas', 'Other Vegetables', 'Citrus Fruit', 'Bananas',
#        'Apples', 'Berries & Grapes', 'Wine', 'Other Fruit', 'Coffee',
#        'Dark Chocolate', 'Bovine Meat (beef herd)',
#        'Bovine Meat (dairy herd)', 'Lamb & Mutton', 'Pig Meat',
#        'Poultry Meat', 'Milk', 'Cheese', 'Eggs', 'Fish (farmed)',
#        'Crustaceans (farmed)', nan], dtype=object)

# %% [markdown]
# # Part 3: Column Operations
# What is this data telling us about food emissions?

# %% [markdown]
# 1. What is the highest mean GHG emissions (per FU) of a food item in this data?

# %%
df_ghg_emissions.highest()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-55-9300516095b4> in <cell line: 0>()
# ----> 1 df_ghg_emissions.highest()
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'DataFrame' object has no attribute 'highest'

# %% [markdown]
# 2. Which food product has that hightest mean GHG emission? Display the entire data row for that item.

# %% [markdown]
# 3. What are the top 10 food items in this data with the highest median GHG emission? Display the entire data rows for those items.

# %% [markdown]
# 4. What is the lowest mean GHG emissions of a food item in this data?

# %% [markdown]
# 5. Which food product has that lowest mean GHG emission? Display the entire data row for that item.

# %% [markdown]
# 6. Looking at the mean and median GHG emissions per food product is one thing, but suppose we are interested in the very edge of the range of recorded GHG emissions in this data.
#
#   What food item has the smallest 5th percentile for GHG emission in this data? Display that row of data.

# %% [markdown]
# # Part 4: Filtering
#
# Some of the values above look suspicious. Let's investigate further.

# %% [markdown]
# 1. Negative emissions values are somewhat unexpected. Check if other food items in this data have a negative value for the 5th percentile of emissions.

# %% [markdown]
# 2. Check if there are negative values in any of the other data fields. Display all rows that have any negative emissions values.

# %% [markdown]
# 3. What is going on here? Is this reasonable? Refer back to the original paper if helpful.
